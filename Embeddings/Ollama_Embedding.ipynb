# %% [markdown]
# # **Ollama**
# Ollama supports embedding models, making it possible to build retrieval augumented generation(RAG) application that combine text prompts with existing documents or other data.

# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embedding = (
    OllamaEmbeddings(model="gemma:2b")  ## By default llama2 module
)
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_15296\1695569049.py:2: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   OllamaEmbeddings(model="gemma:2b")  ## By default llama2 module

# %%
embedding
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1 = embedding.embed_documents(
    [
        "Alpha is the first letter of Greek alphabet",
        "Beta is the second letter of Greek alphabet"
    ]
)

# %%
r1
# Out:
# [[-2.6537065505981445,
#   -0.8678985834121704,
#   0.21470943093299866,
#   2.61238169670105,
#   -0.31524765491485596,
#   0.876210629940033,
#   -0.03610441833734512,
#   0.12336419522762299,
#   0.8589788675308228,
#   -1.4269593954086304,
#   0.7971464991569519,
#   0.7207018733024597,
#   0.6353772282600403,
#   -0.6682666540145874,
#   -0.7202489972114563,
#   -0.013821783475577831,
#   2.9199306964874268,
#   -0.9132547378540039,
#   0.8829686045646667,
#   0.22498337924480438,
#   0.22242721915245056,
#   -0.23905843496322632,
#   0.8473153710365295,
#   0.33336523175239563,
#   -0.6828985810279846,
#   -1.0698044300079346,
#   -0.7092169523239136,
#   0.05042551830410957,
#   0.18840065598487854,
#   1.2604877948760986,
#   -0.13445362448692322,
#   -0.07353273034095764,
#   0.8611342310905457,
#   0.41098418831825256,
#   -1.6636101007461548,
#   -0.0402233824133873,
#   -0.9818496704101562,
#   0.47854918241500854,
#   0.8359699845314026,
#   0.07528278976678848,
# ...

# %%
r1[0]
# Out:
# [-2.6537065505981445,
#  -0.8678985834121704,
#  0.21470943093299866,
#  2.61238169670105,
#  -0.31524765491485596,
#  0.876210629940033,
#  -0.03610441833734512,
#  0.12336419522762299,
#  0.8589788675308228,
#  -1.4269593954086304,
#  0.7971464991569519,
#  0.7207018733024597,
#  0.6353772282600403,
#  -0.6682666540145874,
#  -0.7202489972114563,
#  -0.013821783475577831,
#  2.9199306964874268,
#  -0.9132547378540039,
#  0.8829686045646667,
#  0.22498337924480438,
#  0.22242721915245056,
#  -0.23905843496322632,
#  0.8473153710365295,
#  0.33336523175239563,
#  -0.6828985810279846,
#  -1.0698044300079346,
#  -0.7092169523239136,
#  0.05042551830410957,
#  0.18840065598487854,
#  1.2604877948760986,
#  -0.13445362448692322,
#  -0.07353273034095764,
#  0.8611342310905457,
#  0.41098418831825256,
#  -1.6636101007461548,
#  -0.0402233824133873,
#  -0.9818496704101562,
#  0.47854918241500854,
#  0.8359699845314026,
#  0.07528278976678848,
#  1.6333731412887573,
#  0.7454455494880676,
# ...

# %%
len(r1[0])
# Out:
# 2048

# %%
embedding.embed_query("What is the second letter of Greek alphabet")
# Out:
# [-1.890357255935669,
#  -0.15663500130176544,
#  -0.7663771510124207,
#  1.5567278861999512,
#  -0.5346599221229553,
#  0.4675578773021698,
#  -1.0275919437408447,
#  -0.5294898152351379,
#  -1.0686049461364746,
#  -3.251354217529297,
#  0.40051043033599854,
#  -0.39084187150001526,
#  1.1444449424743652,
#  -0.7977662682533264,
#  0.1876455396413803,
#  -0.1935785859823227,
#  8.425111770629883,
#  -1.2578984498977661,
#  1.5432417392730713,
#  -0.29940536618232727,
#  0.7806451320648193,
#  -1.586179256439209,
#  0.6185466647148132,
#  0.11657880991697311,
#  -1.0901999473571777,
#  -1.7461012601852417,
#  -0.26776355504989624,
#  -0.29910990595817566,
#  0.7929177284240723,
#  1.0616546869277954,
#  -1.0244604349136353,
#  0.136133074760437,
#  2.0977187156677246,
#  -0.8007867336273193,
#  -1.4354294538497925,
#  -0.5380170941352844,
#  -2.3470640182495117,
#  0.9659993052482605,
#  0.16438212990760803,
#  0.026755662634968758,
#  0.6552602052688599,
#  3.064131259918213,
# ...

# %% [markdown]
# ### Other Embedding Models
# ### **https://ollama.com/blog/emedding-models**

# %% [markdown]
# ### ollama pull mxbai-embed-large

# %%
embedding = OllamaEmbeddings(model="mxbai-embed-large")
text = "This is a text document."
query_result = embedding.embed_query(text)
query_result
# Out:
# [0.25762051343917847,
#  -0.6210678219795227,
#  0.6299900412559509,
#  0.5541802644729614,
#  0.10306897759437561,
#  0.2380107343196869,
#  -0.17781588435173035,
#  0.040671300143003464,
#  0.7891151309013367,
#  0.7475100159645081,
#  -0.5509827733039856,
#  0.20709916949272156,
#  -0.2528209090232849,
#  0.1980351060628891,
#  -0.6532258987426758,
#  -0.5280545949935913,
#  -0.41316601634025574,
#  0.06364455819129944,
#  -0.27076634764671326,
#  0.0041626617312431335,
#  -0.71426922082901,
#  0.7031053900718689,
#  -1.8315180540084839,
#  0.06658417731523514,
#  0.06044171750545502,
#  0.06659603863954544,
#  -0.5541527271270752,
#  0.3436422646045685,
#  0.5979593992233276,
#  1.175465703010559,
#  -0.09070003777742386,
#  0.6544440984725952,
#  -0.4685385227203369,
#  -0.31603121757507324,
#  0.4212280511856079,
#  -0.2932581305503845,
#  0.7942022681236267,
#  -0.6784890294075012,
#  0.2721783220767975,
#  -0.46860507130622864,
#  -0.012694350443780422,
# ...

# %%
len(query_result)
# Out:
# 1024

# %%
print("The End")
# Out:
# The End
